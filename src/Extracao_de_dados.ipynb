# %% [markdown]
# ### Leitura do arquivo 1

# %%
file =  open('./data/sobrepython.txt','r', encoding='utf-8')

# %% [markdown]
# ### Exibição do arquivo 1

# %%
file
# Out:
# <_io.TextIOWrapper name='./data/sobrepython.txt' mode='r' encoding='utf-8'>

# %% [markdown]
# ### Leitura do texto dentro do arquivo 1

# %%
file.read()
# Out:
# 'Python é uma linguagem de programação de alto nível,[5] interpretada, de script, imperativa, orientada a objetos, funcional, de tipagem dinâmica e forte. Foi lançada por Guido van Rossum em 1991.[1] Atualmente possui um modelo de desenvolvimento comunitário, aberto e gerenciado pela organização sem fins lucrativos Python Software Foundation. Apesar de várias partes da linguagem possuírem padrões e especificações formais, a linguagem como um todo não é formalmente especificada. O padrão de facto é a implementação CPython.\n\nA linguagem foi projetada com a filosofia de enfatizar a importância do esforço do programador sobre o esforço computacional. Prioriza a legibilidade do código sobre a velocidade ou expressividade. Combina uma sintaxe concisa e clara com os recursos poderosos de sua biblioteca padrão e por módulos e frameworks desenvolvidos por terceiros.\n\nPython é uma linguagem de propósito geral de alto nível, multiparadigma, suporta o paradigma orientado a objetos, imperativ
# ...

# %% [markdown]
# ### Colocando o cursos de leitura no inicio do arquivo 1

# %%
file.seek(0)
# Out:
# 0

# %% [markdown]
# ### Leitura do arquivo 1 separado por linhas

# %%
file.readlines()
# Out:
# ['Python é uma linguagem de programação de alto nível,[5] interpretada, de script, imperativa, orientada a objetos, funcional, de tipagem dinâmica e forte. Foi lançada por Guido van Rossum em 1991.[1] Atualmente possui um modelo de desenvolvimento comunitário, aberto e gerenciado pela organização sem fins lucrativos Python Software Foundation. Apesar de várias partes da linguagem possuírem padrões e especificações formais, a linguagem como um todo não é formalmente especificada. O padrão de facto é a implementação CPython.\n',
#  '\n',
#  'A linguagem foi projetada com a filosofia de enfatizar a importância do esforço do programador sobre o esforço computacional. Prioriza a legibilidade do código sobre a velocidade ou expressividade. Combina uma sintaxe concisa e clara com os recursos poderosos de sua biblioteca padrão e por módulos e frameworks desenvolvidos por terceiros.\n',
#  '\n',
# ...

# %% [markdown]
# ### Leitura do arquivo 2

# %%
file2 = open('./data/AAPL.csv', 'r', encoding='utf-8')

# %% [markdown]
# ### Leitura do texto dentro do arquivo 2

# %%
file2.readlines()
# Out:
# ['date,open,close\n',
#  '2003-01-02,14.36,14.8\n',
#  '2003-01-03,14.8,14.9\n',
#  '2003-01-06,15.03,14.9\n',
#  '2003-01-07,14.79,14.85\n',
#  '2003-01-08,14.58,14.55\n',
#  '2003-01-09,14.62,14.68\n',
#  '2003-01-10,14.58,14.72\n',
#  '2003-01-13,14.9,14.63\n',
#  '2003-01-14,14.69,14.61\n',
#  '2003-01-15,14.59,14.43\n',
#  '2003-01-16,14.21,14.62\n',
#  '2003-01-17,14.56,14.1\n',
#  '2003-01-21,14.21,14.02\n',
#  '2003-01-22,13.98,13.88\n',
#  '2003-01-23,14.05,14.17\n',
#  '2003-01-24,14.24,13.8\n',
#  '2003-01-27,13.68,14.13\n',
#  '2003-01-28,14.24,14.58\n',
#  '2003-01-29,14.24,14.58\n',
#  '2003-01-30,14.98,14.32\n',
#  '2003-01-31,14.19,14.36\n',
#  '2003-02-03,14.41,14.66\n',
#  '2003-02-04,14.45,14.6\n',
#  '2003-02-05,14.71,14.45\n',
#  '2003-02-06,14.36,14.43\n',
#  '2003-02-07,14.55,14.15\n',
#  '2003-02-10,14.26,14.35\n',
#  '2003-02-11,14.5,14.35\n',
#  '2003-02-12,14.27,14.39\n',
#  '2003-02-13,14.41,14.54\n',
#  '2003-02-14,14.61,14.67\n',
# ...

# %% [markdown]
# ### importando a biblioteca Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Trabalhando com Series no Pandas

# %%
notas = pd.Series([10,9,7,9])

# %%
notas
# Out:
# 0    10
# 1     9
# 2     7
# 3     9
# dtype: int64

# %%
notas.sum()
# Out:
# 35

# %%
notas.std()
# Out:
# 1.2583057392117916

# %% [markdown]
# ### Trabalhando com DataFrame no Pandas

# %%
df = pd.DataFrame(
    {
        "Alunos":["Leonardo", "Alfredo", "Abel", "Julia"],
        "Faltas":[1,3,4,0],
        "Notas":[10,9.8,4.5,8.5]
    }
)

# %%
df
# Out:
#      Alunos  Faltas  Notas
# 0  Leonardo       1   10.0
# 1   Alfredo       3    9.8
# 2      Abel       4    4.5
# 3     Julia       0    8.5

# %%
df.iloc[0]
# Out:
# Alunos    Leonardo
# Faltas           1
# Notas           10
# Name: 0, dtype: object

# %%
df.columns
# Out:
# Index(['Alunos', 'Faltas', 'Notas'], dtype='object')

# %%
df.dtypes
# Out:
# Alunos     object
# Faltas      int64
# Notas     float64
# dtype: object

# %%
df['Notas'] > 9
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# Name: Notas, dtype: bool

# %%
df[df['Notas'] > 9]
# Out:
#      Alunos  Faltas  Notas
# 0  Leonardo       1   10.0
# 1   Alfredo       3    9.8

# %% [markdown]
# ### Lendo arquivo com Pandas

# %%
fileApple = pd.read_csv("./data/AAPL.csv", sep=",")

# %%
fileApple
# Out:
#             date    open   close
# 0     2003-01-02   14.36   14.80
# 1     2003-01-03   14.80   14.90
# 2     2003-01-06   15.03   14.90
# 3     2003-01-07   14.79   14.85
# 4     2003-01-08   14.58   14.55
# ...          ...     ...     ...
# 1253  2007-12-24  195.03  198.80
# 1254  2007-12-26  199.01  198.95
# 1255  2007-12-27  198.95  198.57
# 1256  2007-12-28  200.59  199.83
# 1257  2007-12-31  199.50  198.08
#
# [1258 rows x 3 columns]

# %%
fileApple.head(5)
# Out:
#          date   open  close
# 0  2003-01-02  14.36  14.80
# 1  2003-01-03  14.80  14.90
# 2  2003-01-06  15.03  14.90
# 3  2003-01-07  14.79  14.85
# 4  2003-01-08  14.58  14.55

# %%
fileApple.tail(5)
# Out:
#             date    open   close
# 1253  2007-12-24  195.03  198.80
# 1254  2007-12-26  199.01  198.95
# 1255  2007-12-27  198.95  198.57
# 1256  2007-12-28  200.59  199.83
# 1257  2007-12-31  199.50  198.08

# %%
fileApple.tail(7)[['close']].mean()
# Out:
# close    196.478571
# dtype: float64

# %%
fileApple.describe()
# Out:
#               open        close
# count  1258.000000  1258.000000
# mean     61.074007    61.050507
# std      42.224530    42.140624
# min      12.990000    13.120000
# 25%      26.702500    26.680000
# 50%      54.030000    53.920000
# 75%      79.220000    79.512500
# max     200.590000   199.830000

# %% [markdown]
# ### Lendo HTML com Pandas

# %%
url = 'https://www.contextures.com/xlsampledata01.html'

# %%
tabela = pd.read_html(url)

# %%
tabela
# Out:
# [             0        1         2        3      4         5        6
#  0    OrderDate   Region       Rep     Item  Units  UnitCost    Total
#  1     1/6/2019     East     Jones   Pencil     95      1.99   189.05
#  2    1/23/2019  Central    Kivell   Binder     50     19.99   999.50
#  3     2/9/2019  Central   Jardine   Pencil     36      4.99   179.64
#  4    2/26/2019  Central      Gill      Pen     27     19.99   539.73
#  5    3/15/2019     West   Sorvino   Pencil     56      2.99   167.44
#  6     4/1/2019     East     Jones   Binder     60      4.99   299.40
#  7    4/18/2019  Central   Andrews   Pencil     75      1.99   149.25
#  8     5/5/2019  Central   Jardine   Pencil     90      4.99   449.10
#  9    5/22/2019     West  Thompson   Pencil     32      1.99    63.68
#  10    6/8/2019     East     Jones   Binder     60      8.99   539.40
#  11   6/25/2019  Central    Morgan   Pencil     90      4.99   449.10
# ...

# %%
tabela[0]
# Out:
#              0        1         2        3      4         5        6
# 0    OrderDate   Region       Rep     Item  Units  UnitCost    Total
# 1     1/6/2019     East     Jones   Pencil     95      1.99   189.05
# 2    1/23/2019  Central    Kivell   Binder     50     19.99   999.50
# 3     2/9/2019  Central   Jardine   Pencil     36      4.99   179.64
# 4    2/26/2019  Central      Gill      Pen     27     19.99   539.73
# 5    3/15/2019     West   Sorvino   Pencil     56      2.99   167.44
# 6     4/1/2019     East     Jones   Binder     60      4.99   299.40
# 7    4/18/2019  Central   Andrews   Pencil     75      1.99   149.25
# 8     5/5/2019  Central   Jardine   Pencil     90      4.99   449.10
# 9    5/22/2019     West  Thompson   Pencil     32      1.99    63.68
# 10    6/8/2019     East     Jones   Binder     60      8.99   539.40
# 11   6/25/2019  Central    Morgan   Pencil     90      4.99   449.10
# 12   7/12/2019     East    Howard   Binder     29      1.99    57.71
# ...

# %%
len(tabela)
# Out:
# 1
