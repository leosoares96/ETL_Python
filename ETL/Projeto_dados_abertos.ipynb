# %% [markdown]
# # Projeto utilizando dados abertos

# %% [markdown]
# ### Objetivo: Armazenas os gastos (até o momento) por deputado federal
#     1. Obter os dados
#     2. Realizar ajustes necessários
#     3. Armazenar no sqlite

# %% [markdown]
# #### Importação das bibliotecas

# %%
import pandas as pd
import requests

# %% [markdown]
# #### Buscando lista de deputados através da API

# %%
url_deputados = 'https://dadosabertos.camara.leg.br/api/v2/deputados?ordem=ASC&ordenarPor=nome'

resultado = requests.get(url_deputados)

# %%
deputados = pd.DataFrame(resultado.json()['dados'])

# %%
deputados.head()
# Out:
#        id                                                uri             nome  \
# 0  204554  https://dadosabertos.camara.leg.br/api/v2/depu...   Abílio Santana
# 1  204521  https://dadosabertos.camara.leg.br/api/v2/depu...        Abou Anni
# 2  204379  https://dadosabertos.camara.leg.br/api/v2/depu...   Acácio Favacho
# 3  204560  https://dadosabertos.camara.leg.br/api/v2/depu...     Adolfo Viana
# 4  204528  https://dadosabertos.camara.leg.br/api/v2/depu...  Adriana Ventura
#
#   siglaPartido                                         uriPartido siglaUf  \
# 0           PL  https://dadosabertos.camara.leg.br/api/v2/part...      BA
# 1          PSL  https://dadosabertos.camara.leg.br/api/v2/part...      SP
# 2         PROS  https://dadosabertos.camara.leg.br/api/v2/part...      AP
# 3         PSDB  https://dadosabertos.camara.leg.br/api/v2/part...      BA
# 4         NOVO  https://dadosabertos.camara.leg.br/api/v2/part...      SP
#
#    idLegislatura                                            urlFoto  \
# 0             56  https://www.camara.leg.br/internet/deputado/ba...
# 1             56  https://www.camara.leg.br/internet/deputado/ba...
# 2             56  https://www.camara.leg.br/internet/deputado/ba...
# 3             56  https://www.camara.leg.br/internet/deputado/ba...
# 4             56  https://www.camara.leg.br/internet/deputado/ba...
#
#                               email
# 0   dep.abiliosantana@camara.leg.br
# 1        dep.abouanni@camara.leg.br
# 2   dep.acaciofavacho@camara.leg.br
# 3     dep.adolfoviana@camara.leg.br
# 4  dep.adrianaventura@camara.leg.br

# %%
deputados.shape
# Out:
# (513, 9)

# %% [markdown]
# #### Buscando dados de despesas por deputados através da API

# %%
despesas = []

for id in deputados.id:
    url_despesas = 'https://dadosabertos.camara.leg.br/api/v2/deputados/' + str(id) + '/despesas?ordem=ASC&ano=2021'
    response = requests.get(url_despesas)
    despesa = pd.DataFrame(response.json()['dados'])
    despesa['id'] = id    
    despesas.append(despesa)

# %%
despesas[1]
# Out:
#      ano  mes                                 tipoDespesa  codDocumento  \
# 0   2021    1               COMBUSTÍVEIS E LUBRIFICANTES.       7138238
# 1   2021    1                  PASSAGEM AÉREA - REEMBOLSO       7141292
# 2   2021    1                                   TELEFONIA       7141291
# 3   2021    1                                   TELEFONIA       7141286
# 4   2021    1  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR       7138237
# 5   2021    1  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR       7141271
# 6   2021    1   SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO       7141298
# 7   2021    1   SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO       7141302
# 8   2021    1   SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO       7141296
# 9   2021    1   SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO       7141303
# 10  2021    1   SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO       7141300
# 11  2021    1   SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO       7141297
# 12  2021    1   SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO       7141295
# 13  2021    1   SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO       7141304
# 14  2021    1   SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO       7141306
#
#      tipoDocumento  codTipoDocumento dataDocumento   numDocumento  \
# 0      Nota Fiscal                 0    2021-01-04           4338
# 1      Nota Fiscal                 0    2021-01-11  9572140207167
# 2      Nota Fiscal                 0    2021-01-01       17094028
# 3      Nota Fiscal                 0    2021-01-01      171072860
# 4      Nota Fiscal                 0    2021-01-04         023529
# 5      Nota Fiscal                 0    2021-01-06         007915
# 6   Recibos/Outros                 1    2021-01-12           1201
# 7   Recibos/Outros                 1    2021-01-12       12012021
# 8   Recibos/Outros                 1    2021-01-13           1301
# 9   Recibos/Outros                 1    2021-01-12           2701
# 10  Recibos/Outros                 1    2021-01-12           3742
# 11  Recibos/Outros                 1    2021-01-12           7816
# 12  Recibos/Outros                 1    2021-01-13           8711
# 13  Recibos/Outros                 1    2021-01-13       13012021
# 14  Recibos/Outros                 1    2021-01-13           2055
#
#     valorDocumento                                       urlDocumento  \
# 0           190.00  https://www.camara.leg.br/cota-parlamentar/doc...
# 1          3221.94  https://www.camara.leg.br/cota-parlamentar/doc...
# 2            91.86                                               None
# 3           205.57                                               None
# 4            45.80  https://www.camara.leg.br/cota-parlamentar/doc...
# 5            26.90  https://www.camara.leg.br/cota-parlamentar/doc...
# 6             7.00  https://www.camara.leg.br/cota-parlamentar/doc...
# 7            22.20  https://www.camara.leg.br/cota-parlamentar/doc...
# 8             7.10  https://www.camara.leg.br/cota-parlamentar/doc...
# 9            11.47  https://www.camara.leg.br/cota-parlamentar/doc...
# 10            6.00  https://www.camara.leg.br/cota-parlamentar/doc...
# 11           20.00  https://www.camara.leg.br/cota-parlamentar/doc...
# 12           10.20  https://www.camara.leg.br/cota-parlamentar/doc...
# 13           23.20  https://www.camara.leg.br/cota-parlamentar/doc...
# 14            8.37  https://www.camara.leg.br/cota-parlamentar/doc...
#
#                              nomeFornecedor cnpjCpfFornecedor  valorLiquido  \
# 0   PEGASUS DA BANDEIRANTES AUTO POSTO LTDA    15809084000186        190.00
# 1                                     LATAM    02012862000160       3221.94
# 2              Telefônica Brasil S. A. VIVO    02558157000162         89.99
# 3              Telefônica Brasil S. A. VIVO    02558157000162        163.36
# 4             Piemonte pizza e cozinha ltda    08166424000132         45.80
# 5             SAN JUAN SAO PAULO HOTEL LTDA    00825082000103         26.90
# 6                                    99 POP    18033552000161          7.00
# 7                                    99 POP    18033552000161         22.20
# 8                                    99 POP    18033552000161          7.10
# 9                                    99 POP    18033552000161         11.47
# 10                                   99 POP    18033552000161          6.00
# 11                                   99 POP    18033552000161         20.00
# 12                                   99 POP    18033552000161         10.20
# 13                       99 TECNOLOGIA LTDA    18033552000161         23.20
# 14                       99 TECNOLOGIA LTDA    18033552000161          8.37
#
#     valorGlosa numRessarcimento  codLote  parcela      id
# 0         0.00                   1737636        0  204521
# 1         0.00                   1739126        0  204521
# 2         1.87                   1739124        0  204521
# 3        42.21                   1739124        0  204521
# 4         0.00                   1737637        0  204521
# 5         0.00                   1739124        0  204521
# 6         0.00                   1739124        0  204521
# 7         0.00                   1739124        0  204521
# 8         0.00                   1739124        0  204521
# 9         0.00                   1739124        0  204521
# 10        0.00                   1739124        0  204521
# 11        0.00                   1739124        0  204521
# 12        0.00                   1739124        0  204521
# 13        0.00                   1739125        0  204521
# 14        0.00                   1739125        0  204521

# %% [markdown]
# #### Transformação dos dados

# %%
total = pd.concat(despesas)

# %%
# valores ausentes?
total.isnull().sum()
# Out:
# id                     0
# ano                    0
# mes                    0
# tipoDespesa            0
# codDocumento           0
# tipoDocumento          0
# codTipoDocumento       0
# dataDocumento          0
# numDocumento           0
# valorDocumento         0
# urlDocumento         220
# nomeFornecedor         0
# cnpjCpfFornecedor      0
# valorLiquido           0
# valorGlosa             0
# numRessarcimento       0
# codLote                0
# parcela                0
# dtype: int64

# %%
del total['urlDocumento']

# %%
total.head()
# Out:
#        id     ano  mes                                 tipoDespesa  \
# 0  204521  2021.0  1.0               COMBUSTÍVEIS E LUBRIFICANTES.
# 1  204521  2021.0  1.0                  PASSAGEM AÉREA - REEMBOLSO
# 2  204521  2021.0  1.0                                   TELEFONIA
# 3  204521  2021.0  1.0                                   TELEFONIA
# 4  204521  2021.0  1.0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
#
#    codDocumento tipoDocumento  codTipoDocumento dataDocumento   numDocumento  \
# 0     7138238.0   Nota Fiscal               0.0    2021-01-04           4338
# 1     7141292.0   Nota Fiscal               0.0    2021-01-11  9572140207167
# 2     7141291.0   Nota Fiscal               0.0    2021-01-01       17094028
# 3     7141286.0   Nota Fiscal               0.0    2021-01-01      171072860
# 4     7138237.0   Nota Fiscal               0.0    2021-01-04         023529
#
#    valorDocumento                           nomeFornecedor cnpjCpfFornecedor  \
# 0          190.00  PEGASUS DA BANDEIRANTES AUTO POSTO LTDA    15809084000186
# 1         3221.94                                    LATAM    02012862000160
# 2           91.86             Telefônica Brasil S. A. VIVO    02558157000162
# 3          205.57             Telefônica Brasil S. A. VIVO    02558157000162
# 4           45.80            Piemonte pizza e cozinha ltda    08166424000132
#
#    valorLiquido  valorGlosa numRessarcimento    codLote  parcela
# 0        190.00        0.00                   1737636.0      0.0
# 1       3221.94        0.00                   1739126.0      0.0
# 2         89.99        1.87                   1739124.0      0.0
# 3        163.36       42.21                   1739124.0      0.0
# 4         45.80        0.00                   1737637.0      0.0

# %%
total.numRessarcimento.value_counts()
# Out:
#      719
# 0    194
# Name: numRessarcimento, dtype: int64

# %%
total.shape
# Out:
# (913, 17)

# %%
del total['numRessarcimento']

# %%
print(total.shape)
total.drop_duplicates()
print(total.shape)
# Out:
# (913, 16)
# (913, 16)

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 913 entries, 0 to 1
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 913 non-null    int64
#  1   ano                913 non-null    float64
#  2   mes                913 non-null    float64
#  3   tipoDespesa        913 non-null    object
#  4   codDocumento       913 non-null    float64
#  5   tipoDocumento      913 non-null    object
#  6   codTipoDocumento   913 non-null    float64
#  7   dataDocumento      913 non-null    object
#  8   numDocumento       913 non-null    object
#  9   valorDocumento     913 non-null    float64
#  10  nomeFornecedor     913 non-null    object
#  11  cnpjCpfFornecedor  913 non-null    object
#  12  valorLiquido       913 non-null    float64
#  13  valorGlosa         913 non-null    float64
#  14  codLote            913 non-null    float64
#  15  parcela            913 non-null    float64
# dtypes: float64(9), int64(1), object(6)
# memory usage: 121.3+ KB

# %%
total.valorLiquido.describe()
# Out:
# count      913.000000
# mean       598.869025
# std       2617.632764
# min          2.600000
# 25%         66.770000
# 50%        149.840000
# 75%        244.430000
# max      36000.000000
# Name: valorLiquido, dtype: float64

# %%
total.nomeFornecedor.value_counts()
# Out:
# CORREIOS - SEDEX CONVENCIONAL                                83
# CORREIOS - CARTA COMERCIAL                                   24
# CORREIOS - ENCOMENDA PAC                                     21
# Telefônica Brasil S. A. VIVO                                 19
# CORREIOS - CAIXA DE ENCOMENDAS BÁSICA/CONVENCIONAL           15
#                                                              ..
# TIC POSTO LTDA V                                              1
# ECT - EMP.BRAS.DE CORREIOS E TELEGRAFOS                       1
# CENTRAL COOP                                                  1
# E MENEGATTI COMERCIO DE COMBUSTIVEL LTDA                      1
# CORACAO DE MARIA COMERCIO DE DERIVADOS DE PETROLEO EIRELI     1
# Name: nomeFornecedor, Length: 501, dtype: int64

# %% [markdown]
# #### Carga dos dados

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///dados_abertos.db')

# %%
deputados.to_sql('deputados', engine)

# %%
total.to_sql('despesas', engine)

# %% [markdown]
# #### Analisando os dados

# %%
listaDespesas = pd.read_sql('SELECT * FROM despesas', engine)

# %%
listaDeputados = pd.read_sql('SELECT * FROM deputados', engine)

# %%
data = listaDespesas.merge(listaDeputados, on=['id'])

# %%
data
# Out:
#      index_x      id     ano  mes  \
# 0          0  204521  2021.0  1.0
# 1          1  204521  2021.0  1.0
# 2          2  204521  2021.0  1.0
# 3          3  204521  2021.0  1.0
# 4          4  204521  2021.0  1.0
# ..       ...     ...     ...  ...
# 908        1   74439  2021.0  1.0
# 909        2   74439  2021.0  1.0
# 910        0  204559  2021.0  1.0
# 911        0  160632  2021.0  1.0
# 912        1  160632  2021.0  1.0
#
#                                            tipoDespesa  codDocumento  \
# 0                        COMBUSTÍVEIS E LUBRIFICANTES.     7138238.0
# 1                           PASSAGEM AÉREA - REEMBOLSO     7141292.0
# 2                                            TELEFONIA     7141291.0
# 3                                            TELEFONIA     7141286.0
# 4           FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR     7138237.0
# ..                                                 ...           ...
# 908                                   SERVIÇOS POSTAIS           0.0
# 909                                   SERVIÇOS POSTAIS           0.0
# 910  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...     7138753.0
# 911                                   SERVIÇOS POSTAIS           0.0
# 912                                   SERVIÇOS POSTAIS           0.0
#
#       tipoDocumento  codTipoDocumento dataDocumento   numDocumento  ...  \
# 0       Nota Fiscal               0.0    2021-01-04           4338  ...
# 1       Nota Fiscal               0.0    2021-01-11  9572140207167  ...
# 2       Nota Fiscal               0.0    2021-01-01       17094028  ...
# 3       Nota Fiscal               0.0    2021-01-01      171072860  ...
# 4       Nota Fiscal               0.0    2021-01-04         023529  ...
# ..              ...               ...           ...            ...  ...
# 908  Recibos/Outros               1.0    2021-01-11  RSP : 2310532  ...
# 909  Recibos/Outros               1.0    2021-01-18  RSP : 2310663  ...
# 910     Nota Fiscal               0.0    2021-01-06           1762  ...
# 911  Recibos/Outros               1.0    2021-01-13  RSP : 2310577  ...
# 912  Recibos/Outros               1.0    2021-01-15  RSP : 2310582  ...
#
#      parcela index_y                                                uri  \
# 0        0.0       1  https://dadosabertos.camara.leg.br/api/v2/depu...
# 1        0.0       1  https://dadosabertos.camara.leg.br/api/v2/depu...
# 2        0.0       1  https://dadosabertos.camara.leg.br/api/v2/depu...
# 3        0.0       1  https://dadosabertos.camara.leg.br/api/v2/depu...
# 4        0.0       1  https://dadosabertos.camara.leg.br/api/v2/depu...
# ..       ...     ...                                                ...
# 908      0.0     507  https://dadosabertos.camara.leg.br/api/v2/depu...
# 909      0.0     507  https://dadosabertos.camara.leg.br/api/v2/depu...
# 910      0.0     509  https://dadosabertos.camara.leg.br/api/v2/depu...
# 911      0.0     510  https://dadosabertos.camara.leg.br/api/v2/depu...
# 912      0.0     510  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                nome   siglaPartido  \
# 0         Abou Anni            PSL
# 1         Abou Anni            PSL
# 2         Abou Anni            PSL
# 3         Abou Anni            PSL
# 4         Abou Anni            PSL
# ..              ...            ...
# 908  Wolney Queiroz            PDT
# 909  Wolney Queiroz            PDT
# 910         Zé Neto             PT
# 911        Zé Silva  SOLIDARIEDADE
# 912        Zé Silva  SOLIDARIEDADE
#
#                                             uriPartido  siglaUf  \
# 0    https://dadosabertos.camara.leg.br/api/v2/part...       SP
# 1    https://dadosabertos.camara.leg.br/api/v2/part...       SP
# 2    https://dadosabertos.camara.leg.br/api/v2/part...       SP
# 3    https://dadosabertos.camara.leg.br/api/v2/part...       SP
# 4    https://dadosabertos.camara.leg.br/api/v2/part...       SP
# ..                                                 ...      ...
# 908  https://dadosabertos.camara.leg.br/api/v2/part...       PE
# 909  https://dadosabertos.camara.leg.br/api/v2/part...       PE
# 910  https://dadosabertos.camara.leg.br/api/v2/part...       BA
# 911  https://dadosabertos.camara.leg.br/api/v2/part...       MG
# 912  https://dadosabertos.camara.leg.br/api/v2/part...       MG
#
#      idLegislatura                                            urlFoto  \
# 0               56  https://www.camara.leg.br/internet/deputado/ba...
# 1               56  https://www.camara.leg.br/internet/deputado/ba...
# 2               56  https://www.camara.leg.br/internet/deputado/ba...
# 3               56  https://www.camara.leg.br/internet/deputado/ba...
# 4               56  https://www.camara.leg.br/internet/deputado/ba...
# ..             ...                                                ...
# 908             56  https://www.camara.leg.br/internet/deputado/ba...
# 909             56  https://www.camara.leg.br/internet/deputado/ba...
# 910             56  https://www.camara.leg.br/internet/deputado/ba...
# 911             56  https://www.camara.leg.br/internet/deputado/ba...
# 912             56  https://www.camara.leg.br/internet/deputado/ba...
#
#                                email
# 0         dep.abouanni@camara.leg.br
# 1         dep.abouanni@camara.leg.br
# 2         dep.abouanni@camara.leg.br
# 3         dep.abouanni@camara.leg.br
# 4         dep.abouanni@camara.leg.br
# ..                               ...
# 908  dep.wolneyqueiroz@camara.leg.br
# 909  dep.wolneyqueiroz@camara.leg.br
# 910         dep.zeneto@camara.leg.br
# 911        dep.zesilva@camara.leg.br
# 912        dep.zesilva@camara.leg.br
#
# [913 rows x 26 columns]

# %%
gastosDeputados = data.groupby(['nome']).sum()[['valorDocumento','valorLiquido']]

# %%
gastosDeputados = gastosDeputados.sort_values('valorDocumento', ascending = False)

# %%
gastosDeputados.head(10)
# Out:
#                      valorDocumento  valorLiquido
# nome
# Gonzaga Patriota           39180.30      38676.80
# Wellington Roberto         35057.57      35057.57
# Ruy Carneiro               34300.00      34300.00
# Nivaldo Albuquerque        30000.00      30000.00
# Beto Faro                  23690.00      23690.00
# Cássio Andrade             16568.15      16532.15
# Fernando Rodolfo           13750.54      13750.54
# Áurea Carolina             13214.75      13214.75
# Vander Loubet              12600.00      12600.00
# Gilberto Nascimento        11371.36      11371.36

# %%
gastosDeputados.tail(10)
# Out:
#                                    valorDocumento  valorLiquido
# nome
# Marco Bertaiolli                            34.62         34.62
# Capitão Alberto Neto                        34.62         34.62
# Afonso Florence                             26.30         26.30
# Pastor Eurico                               25.77         25.77
# Joaquim Passarinho                          24.73         24.73
# Neri Geller                                 21.05         21.05
# Professora Dorinha Seabra Rezende           17.01         17.01
# Toninho Wandscheer                          10.67         10.67
# Mauro Lopes                                  8.89          8.89
# Silas Câmara                                 6.70          6.70

# %%
# %matplotlib inline

# %%
total.nomeFornecedor.value_counts()[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>
